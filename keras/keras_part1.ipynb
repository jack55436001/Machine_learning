# %% [markdown]
# ## Sequential model and Functional model

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import plot_model
model = Sequential()
model.add(Dense(32, activation='relu', input_dim=100))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

plot_model(model, to_file = 'model.png')
import numpy as np
data = np.random.random((1000, 100))
labels = np.random.randint(2, size=(1000, 1))

model.fit(data, labels, epochs=10, batch_size=32)
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# C:\Users\user-pc\Anaconda3\lib\site-packages\keras\utils\vis_utils.py in _check_pydot()
#      17         # Attempt to create an image of a blank graph to check the pydot/graphviz installation.
# ---> 18         pydot.Dot.create(pydot.Dot())
#      19     except Exception:  # pydot raises a generic Exception here, so no specific class can be caught.
#
# C:\Users\user-pc\Anaconda3\lib\site-packages\pydot_ng\__init__.py in create(self, prog, format)
#    1889                 raise InvocationException(
# -> 1890                     'GraphViz\'s executables not found')
#    1891
#
# InvocationException: GraphViz's executables not found
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-4b2c0b155ec5> in <module>()
# ...

# %%
from keras.layers import Input, Dense
from keras.models import Model

inputs = Input(shape=(100,))

x = Dense(32, activation='relu')(inputs)
out = Dense(1, activation='sigmoid')(x)

model = Model(inputs=inputs, outputs=out)
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

import numpy as np
data = np.random.random((1000, 100))
labels = np.random.randint(2, size=(1000, 1))

model.fit(data, labels, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 1000/1000 [==============================] - 1s - loss: 0.7140 - acc: 0.4900
# Epoch 2/10
# 1000/1000 [==============================] - 0s - loss: 0.6987 - acc: 0.5190
# Epoch 3/10
# 1000/1000 [==============================] - 0s - loss: 0.6938 - acc: 0.5320
# Epoch 4/10
# 1000/1000 [==============================] - 0s - loss: 0.6892 - acc: 0.5330
# Epoch 5/10
# 1000/1000 [==============================] - 0s - loss: 0.6861 - acc: 0.5540
# Epoch 6/10
# 1000/1000 [==============================] - 0s - loss: 0.6820 - acc: 0.5860
# Epoch 7/10
# 1000/1000 [==============================] - 0s - loss: 0.6784 - acc: 0.5750
# Epoch 8/10
# 1000/1000 [==============================] - 0s - loss: 0.6744 - acc: 0.5900
# Epoch 9/10
# 1000/1000 [==============================] - 0s - loss: 0.6714 - acc: 0.6040
# Epoch 10/10
# 1000/1000 [==============================] - 0s - loss: 0.6649 - acc: 0.6060

# %%
# multiple input
import keras
from keras.layers import Input, LSTM, Dense
from keras.models import Model

shared_lstm = LSTM(64)

tweet_a = Input(shape=(140, 256))
tweet_b = Input(shape=(140, 256))

encoded_a = shared_lstm(tweet_a)
encoded_b = shared_lstm(tweet_b)

merged_vector = keras.layers.concatenate([encoded_a, encoded_b], axis=-1)

# %% [markdown]
# ## Dense layer
#
# keras.layers.core.Dense(units, activation=None, use_bias=True,
#                         kernel_initializer='glorot_uniform',
#                         bias_initializer='zeros',
#                         kernel_regularizer=None,
#                         bias_regularizer=None,
#                         activity_regularizer=None,
#                         kernel_constraint=None,
#                         bias_constraint=None)
#
# units = output dimention
# activation = sigmoid relu softmax ......
#
# ex. model.add(Dense(32, activation='relu', input_dim=100))
#
# ## Dropout
# keras.layers.core.Dropout(rate, noise_shape=None, seed=None)
#
# rate = range from 0~1
#
# ex. model.add(Dropout(0.5))
#
# ## Flatten
# keras.layers.core.Flatten()
#
# ex. model.add(Flatten())
#
# ## Convolution2D
#
# keras.layers.convolutional.Conv2D(filters, kernel_size, strides=(1, 1), padding='valid', data_format=None, dilation_rate=(1, 1), activation=None, use_bias=True, kernel_initializer='glorot_uniform', bias_initializer='zeros', kernel_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, bias_constraint=None)
#
# filters = output dimention
# kernel_size = filter row and column
# activation = same as above
#
# ex. model.add(Convolution2D(64, 3, 3, activation='relu', name='conv1_1'))
#
# ## MaxPooling2D
#
# keras.layers.pooling.MaxPooling2D(pool_size=(2, 2), strides=None, padding='valid', data_format=None)
#
# pool_size = (2,2) the pooling factor (2,2) represent that column and row will be half of size in output
#
# ex. model.add(MaxPooling2D((2, 2), strides=(2, 2)))

# %%
from keras.applications.resnet50 import ResNet50
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input, decode_predictions

model = ResNet50(weights='imagenet')
model.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ...
# input_26 (InputLayer)            (None, 224, 224, 3)   0
# ____________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D) (None, 230, 230, 3)   0           input_26[0][0]
# ____________________________________________________________________________________________________
# conv1 (Conv2D)                   (None, 112, 112, 64)  9472        zero_padding2d_3[0][0]
# ____________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)    (None, 112, 112, 64)  256         conv1[0][0]
# ____________________________________________________________________________________________________
# activation_99 (Activation)       (None, 112, 112, 64)  0           bn_conv1[0][0]
# ...

# %%
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input

model = VGG16(weights='imagenet', include_top=False)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_28 (InputLayer)        (None, None, None, 3)     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# ...
